# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
raw_dataset=pd.read_csv("DadasBI3D.csv",sep=",")

# %%
DadasBI3D = raw_dataset.copy()
DadasBI3D.head()
# Out:
#           Well   Latitude  Longitude   Depth_m    BI
# 0  ABDULAZIZ-1  38.345084   39.805726   2740.0  0.27
# 1  ABDULAZIZ-1  38.345084   39.805726   2750.0  0.49
# 2  ABDULAZIZ-1  38.345084   39.805726   2760.0  0.47
# 3  ABDULAZIZ-1  38.345084   39.805726   2780.0  0.56
# 4  ABDULAZIZ-1  38.345084   39.805726   2790.0  0.23

# %%
DadasBI3D.describe()
# Out:
#          Latitude  Longitude       Depth_m          BI
# count  159.000000  159.000000   159.000000  159.000000
# mean    37.821512   40.383201  2859.432075    0.568302
# std      0.412799    0.617857   396.698621    0.168753
# min     37.229614   39.720608  2370.000000    0.230000
# 25%     37.287216   39.803005  2423.600000    0.435000
# 50%     38.003842   40.671948  2870.000000    0.560000
# 75%     38.120595   40.852749  3070.000000    0.685000
# max     38.345084   41.482876  3735.000000    0.970000

# %%
DadasBI3D.shape
# Out:
# (159, 5)

# %%
x= DadasBI3D.iloc[:, 1].values
y=DadasBI3D.iloc[:, 2].values
z = DadasBI3D.iloc[:, 3].values
colors= DadasBI3D.iloc[:, 4].values
sizes= DadasBI3D.iloc[:, 4].values*3

# %%
x
# Out:
# array([38.345084, 38.345084, 38.345084, 38.345084, 38.345084, 38.345084,
#        38.345084, 38.345084, 38.345084, 38.345084, 38.345084, 38.345084,
#        38.345084, 38.345084, 38.345084, 38.345084, 38.345084, 38.120595,
#        38.120595, 38.120595, 38.120595, 38.120595, 38.120595, 38.120595,
#        38.120595, 38.120595, 38.120595, 38.120595, 38.120595, 38.120595,
#        38.120595, 38.149422, 38.149422, 38.149422, 38.149422, 38.149422,
#        38.149422, 38.149422, 38.149422, 38.149422, 38.149422, 38.149422,
#        38.149422, 38.149422, 38.149422, 38.149422, 38.149422, 38.149422,
#        38.149422, 38.149422, 38.149422, 37.229614, 37.229614, 37.229614,
#        37.229614, 37.229614, 37.229614, 37.229614, 37.229614, 37.229614,
#        37.229614, 37.229614, 37.229614, 37.229614, 37.229614, 37.229614,
#        37.229614, 37.229614, 37.229614, 38.086555, 38.086555, 38.086555,
#        38.086555, 38.086555, 38.086555, 38.086555, 38.017136, 38.017136,
#        38.017136, 38.017136, 38.017136, 38.017136, 38.017136, 38.017136,
#        38.017136, 38.017136, 38.017136, 38.116071, 38.116071, 38.116071,
#        38.116071, 38.116071, 38.116071, 38.116071, 38.116071, 38.116071,
#        38.116071, 37.287216, 37.287216, 37.287216, 37.287216, 37.287216,
#        37.287216, 37.287216, 37.287216, 37.287216, 37.287216, 37.287216,
#        37.287216, 37.287216, 37.287216, 37.287216, 37.287216, 37.287216,
#        37.287216, 37.287216, 37.287216, 37.287216, 37.287216, 37.287216,
#        37.287216, 37.287216, 37.287216, 37.287216, 37.287216, 37.287216,
#        0.58, 0.42, 0.43, 0.49, 0.53])

# %%
sizes
# Out:
# array([ 5.4,  9.8,  9.4, 11.2,  4.6, 11.2,  4.6, 11.6, 12. , 11.2, 10.8,
#        11.2, 10.8,  9.2, 10.2, 12. ,  7.2, 13.8, 17.8, 11.6, 14.4, 14.4,
#        11.6, 11.4, 14.6,  9.6, 11.8, 10.6, 12.6, 13. , 13.8, 11.6,  9.6,
#        11.6, 10.6,  9.6, 11.2, 12.2,  9.8, 11.2, 10.2, 13.2,  9.8,  9. ,
#        10.8, 11.4, 11. , 11.2,  9.8,  9.8, 12.4, 16.4, 15.6, 13.6, 12.4,
#        13.4, 14.4, 13.2, 15.2, 15.2, 16.2, 17.2, 18.2, 16.8, 15. , 18. ,
#        18.2, 17.6, 15.4, 13.8,  6.6,  5.4, 16.2, 16.6,  6.8, 14.6, 15.4,
#        14.6, 11.2, 14.8, 14.6,  5.4, 11.8,  6.2,  5.2,  4.8,  6.6, 14.4,
#         7.6, 12.2, 11. , 10.4, 10.4, 15.6,  6.8, 12.2,  6.6, 12. , 10.4,
#        11.8, 13. , 11.8, 16. , 10. , 12.6,  8.2,  8.2, 17.6, 18. , 13.4,
#        19.4, 18.6, 14.4, 10.6,  7.6,  8.2,  7.8,  7.8,  9.8, 13.4,  8.8,
#         9.4,  8.6,  8.4, 10.2,  7.4,  7.2,  9.2,  8.2,  6.8,  8.2,  8.6,
#         8.4,  7.8,  7.6, 15.2,  8.8,  7.4, 12.8,  7.8, 12.4,  9.4, 13.2,
#         8. ,  6.4, 16.6, 15.6, 16.6,  8.6, 13. , 13.2, 10.6,  8.6,  9.4,
#        11.6,  8.4,  8.6,  9.8, 10.6])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import ipywidgets as widgets
from ipywidgets import interactive
from IPython.display import display



# İnteraktif işlev

def plot_3d_scatter(elev, azim, zoom, theta):
    fig = plt.figure(figsize=(25, 10))
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(x, y, z, c=colors, cmap='jet')
    cbar = plt.colorbar(ax.scatter(x, y, z, c=colors, cmap='jet'))
    cbar.set_label('BI')

    ax.view_init(elev=elev, azim=azim)
    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel('Depth_m')
    ax.dist = zoom  # Zoom ayarı
    ax.azim = theta  # Maus ile çevirme
    plt.show()

# İnteraktif widget'ı oluşturma
elev_slider = widgets.IntSlider(min=0, max=180, value=30, description='Elevation:')
azim_slider = widgets.IntSlider(min=0, max=360, value=30, description='Azimuth:')
zoom_slider = widgets.FloatSlider(min=1, max=10, value=5, description='Zoom:')
theta_slider = widgets.IntSlider(min=0, max=360, value=30, description='Theta:')
interactive_plot = interactive(plot_3d_scatter, elev=elev_slider, azim=azim_slider, zoom=zoom_slider, theta=theta_slider)
# Adjust font size
plt.rc('font', size=12)
# Widget'ı görüntüleme
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=30, description='Elevation:', max=180), IntSlider(value=30, description=…
